# %% [markdown]
# # LangChain: Memory
#
# ## Outline
# * ConversationBufferMemory
# * ConversationBufferWindowMemory
# * ConversationTokenBufferMemory
# * ConversationSummaryMemory

# %%
import os
from openai import OpenAI

# %%
dbutils.widgets.text("base_llm_model", "databricks-meta-llama-3-3-70b-instruct")
base_llm_model = dbutils.widgets.get("base_llm_model")
embedding_model = "databricks-gte-large-en"

# %%
from databricks_langchain import ChatDatabricks
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory

# %%
llm = ChatDatabricks(
    endpoint = base_llm_model,
    extra_params = {"temperature": 0.0}
)
llm

# %% [markdown]
# ## ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
conversation = ConversationChain(
  llm = llm,
  memory = memory,
  verbose = True
)

# %%
conversation.predict(input = "Hi, my name is Raj?")

# %%
conversation.predict(input = "Let me confirm that, my name is Raj.")

# %%
conversation.predict(input = "What is my name?")

# %%
print(memory.buffer)

# %%
memory.load_memory_variables({})

# %%
memory = ConversationBufferMemory()

# %%
memory.save_context({"input": "Hi"},
                    {"output": "What's up"})

# %%
print(memory.buffer)

# %%
memory.load_memory_variables({})

# %%
memory.save_context({"input": "Not much, just hanging"}, 
                    {"output": "Cool"})

# %%
memory.load_memory_variables({})
